# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
π=np.pi
x=np.linspace(-1*π,1*π,1000)
y=np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.scatter(x[y>0],y[y>0], c='#007799')
plt.plot(x,y)
