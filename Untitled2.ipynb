# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y=np.linspace(-5,5,100)
x=np.tan(4*y)
plt.plot(x,y)

# %%
r=10
t=np.linspace(-2*np.pi,2*np.pi,200)

x=r*np.cos(t)
y=r*np.sin(t)

plt.plot(x,y)
